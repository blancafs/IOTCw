# %% [markdown]
# # Welcome to Ari and Blanca's IOT Cw!

# %% [markdown]
# ### Below is the work for Week 1:
#
#   ##### - Collection of sensor data from gyroscope and accelerometer on the Nordic Thingy.
#   ##### - Graphs to try and identify steps.

# %%
# Imports
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import seaborn
from scipy.signal import find_peaks

# %%
# First data
df = pd.read_csv('../data_csvs/PDIoT_A_20190918T131131.csv', encoding='utf-8')
print(df.columns)
print(df.shape)
df
# Out:
# Index(['seq', 'accel_x', 'accel_y', 'accel_z', 'gyro_x', 'gyro_y', 'gyro_z',
#        'upper_leg', 'left_right', 'pocket', 'steps'],
#       dtype='object')
# (136, 11)
#      seq   accel_x   accel_y   accel_z    gyro_x    gyro_y    gyro_z  \
# 0      0 -0.182617  0.994141 -0.013672   0.09375 -46.03125   0.00000
# 1      1 -0.140625  0.999023  0.006836  -1.00000 -35.34375  -1.06250
# 2      2 -0.147461  0.992188  0.009766   0.21875 -24.37500  -1.12500
# 3      3 -0.162109  0.986328  0.043945   1.15625 -19.53125  -1.18750
# 4      4 -0.145508  0.989258  0.059570   1.56250  -8.68750   0.15625
# ..   ...       ...       ...       ...       ...       ...       ...
# 131  131  0.205078  0.952148 -0.098633  10.06250   5.90625  93.56250
# 132  132  0.364258  0.919922 -0.123047 -15.62500   9.62500  33.06250
# 133  133  0.348633  0.943359 -0.048828 -19.18750   7.50000  27.15625
# 134  134  0.417969  0.912109 -0.020508  -6.84375  -0.18750  49.65625
# ...

# %%
accels = df.plot(y=['accel_x', 'accel_y', 'accel_z'])

# %%
gyros = df.plot(y=['gyro_x', 'gyro_y', 'gyro_z'])

# %%
# Seeing gyro readings individually
gyro_sequences = [df['gyro_x'].values, df['gyro_y'].values, df['gyro_z'].values]
i = 0 
gps = []
for r in gyro_sequences:
    peaks, _ = find_peaks(r, height=0)
    plt.plot(r)
    plt.plot(peaks, r[peaks], "r")
    plt.plot(np.zeros_like(r), "--", color="gray")
    t = 'Gyro_'+str(i)
    plt.title(t)
    i+=1
    plt.show()
    gps.append(plt)
